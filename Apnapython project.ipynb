# %%
print("hello")
# Out:
# hello

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\akash\\Desktop\\sandhyapython'

# %%
import pandas as pd

# %%
data = pd.read_excel("Data set.xlsx")

# %%
data.head()
# Out:
#         Date  Coal_RB_4800_FOB_London_Close_USD  \
# 0 2020-04-02                              41.00
# 1 2020-04-03                              40.34
# 2 2020-04-06                              40.34
# 3 2020-04-07                              40.34
# 4 2020-04-08                              40.34
#
#    Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 0                              53.22                               64.7
# 1                              52.36                               63.1
# 2                              52.36                               63.1
# 3                              52.36                               63.1
# 4                              52.36                               63.1
#
#    Coal_RB_6000_FOB_CurrentWeek_Avg_USD  Coal_India_5500_CFR_London_Close_USD  \
# 0                                 97.56                                 60.50
# 1                                 70.57                                 62.03
# ...

# %%
data.tail()
# Out:
#            Date  Coal_RB_4800_FOB_London_Close_USD  \
# 1102 2024-06-24                              73.30
# 1103 2024-06-25                              73.30
# 1104 2024-06-26                              73.30
# 1105 2024-06-27                              73.30
# 1106 2024-06-28                              71.38
#
#       Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 1102                              94.56                             107.31
# 1103                              94.56                             107.31
# 1104                              94.56                             107.31
# 1105                              94.56                             107.31
# 1106                              92.08                             103.68
#
#       Coal_RB_6000_FOB_CurrentWeek_Avg_USD  \
# 1102                                106.22
# 1103                                106.22
# 1104                                106.22
# ...

# %%
data.shape
# Out:
# (1107, 19)

# %%
data.describe()
# Out:
#                                 Date  Coal_RB_4800_FOB_London_Close_USD  \
# count                           1107                        1068.000000
# mean   2022-05-16 14:22:26.341463296                          87.953184
# min              2020-04-02 00:00:00                          26.750000
# 25%              2021-04-24 12:00:00                          50.370000
# 50%              2022-05-17 00:00:00                          76.190000
# 75%              2023-06-07 12:00:00                         104.180000
# max              2024-06-28 00:00:00                         301.090000
# std                              NaN                          47.303473
#
#        Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# count                        1068.000000                        1068.000000
# mean                          113.353155                         134.971807
# min                            34.560000                          44.690000
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Coal_RB_4800_FOB_London_Close_USD',
#        'Coal_RB_5500_FOB_London_Close_USD',
#        'Coal_RB_5700_FOB_London_Close_USD',
#        'Coal_RB_6000_FOB_CurrentWeek_Avg_USD',
#        'Coal_India_5500_CFR_London_Close_USD', 'Price_WTI', 'Price_Brent_Oil',
#        'Price_Dubai_Brent_Oil', 'Price_ExxonMobil', 'Price_Shenhua',
#        'Price_All_Share', 'Price_Mining',
#        'Price_LNG_Japan_Korea_Marker_PLATTS', 'Price_ZAR_USD',
#        'Price_Natural_Gas', 'Price_ICE', 'Price_Dutch_TTF',
#        'Price_Indian_en_exg_rate'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Date                                    1107
# Coal_RB_4800_FOB_London_Close_USD        221
# Coal_RB_5500_FOB_London_Close_USD        221
# Coal_RB_5700_FOB_London_Close_USD        217
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD     221
# Coal_India_5500_CFR_London_Close_USD     223
# Price_WTI                                989
# Price_Brent_Oil                          998
# Price_Dubai_Brent_Oil                    935
# Price_ExxonMobil                         995
# Price_Shenhua                            443
# Price_All_Share                         1058
# Price_Mining                            1058
# Price_LNG_Japan_Korea_Marker_PLATTS      892
# Price_ZAR_USD                            798
# Price_Natural_Gas                        937
# Price_ICE                                935
# Price_Dutch_TTF                         1043
# Price_Indian_en_exg_rate                 904
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date                                     0
# Coal_RB_4800_FOB_London_Close_USD       39
# Coal_RB_5500_FOB_London_Close_USD       39
# Coal_RB_5700_FOB_London_Close_USD       39
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    23
# Coal_India_5500_CFR_London_Close_USD    39
# Price_WTI                                8
# Price_Brent_Oil                         11
# Price_Dubai_Brent_Oil                   40
# Price_ExxonMobil                        40
# Price_Shenhua                           65
# Price_All_Share                         49
# Price_Mining                            49
# Price_LNG_Japan_Korea_Marker_PLATTS     41
# Price_ZAR_USD                            0
# Price_Natural_Gas                        8
# Price_ICE                               40
# Price_Dutch_TTF                         31
# Price_Indian_en_exg_rate                60
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  1107 non-null   datetime64[ns]
#  1   Coal_RB_4800_FOB_London_Close_USD     1068 non-null   float64
#  2   Coal_RB_5500_FOB_London_Close_USD     1068 non-null   float64
#  3   Coal_RB_5700_FOB_London_Close_USD     1068 non-null   float64
#  4   Coal_RB_6000_FOB_CurrentWeek_Avg_USD  1084 non-null   float64
#  5   Coal_India_5500_CFR_London_Close_USD  1068 non-null   float64
#  6   Price_WTI                             1099 non-null   float64
#  7   Price_Brent_Oil                       1096 non-null   float64
#  8   Price_Dubai_Brent_Oil                 1067 non-null   float64
#  9   Price_ExxonMobil                      1067 non-null   float64
# ...

# %%
corelation = data.corr()

# %%
import seaborn as sns

sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns
            ,annot=True)
# Out:
# <Axes: >

# %%
data.hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()

sns.boxplot(data=data)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.show()

# %%
import pandas as pd
data = pd.read_excel("Data set.xlsx")
data.isnull().sum()
# Out:
# Date                                     0
# Coal_RB_4800_FOB_London_Close_USD       39
# Coal_RB_5500_FOB_London_Close_USD       39
# Coal_RB_5700_FOB_London_Close_USD       39
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    23
# Coal_India_5500_CFR_London_Close_USD    39
# Price_WTI                                8
# Price_Brent_Oil                         11
# Price_Dubai_Brent_Oil                   40
# Price_ExxonMobil                        40
# Price_Shenhua                           65
# Price_All_Share                         49
# Price_Mining                            49
# Price_LNG_Japan_Korea_Marker_PLATTS     41
# Price_ZAR_USD                            0
# Price_Natural_Gas                        8
# Price_ICE                               40
# Price_Dutch_TTF                         31
# Price_Indian_en_exg_rate                60
# dtype: int64

# %%
-data1 = data.fillna(value= 0)
data1
# Out:
#   Cell In[9], line 1
#     -data1 = data.fillna(value= 0)
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
data1 = data.fillna(value= 0)
data1
# Out:
#            Date  Coal_RB_4800_FOB_London_Close_USD  \
# 0    2020-04-02                              41.00
# 1    2020-04-03                              40.34
# 2    2020-04-06                              40.34
# 3    2020-04-07                              40.34
# 4    2020-04-08                              40.34
# ...         ...                                ...
# 1102 2024-06-24                              73.30
# 1103 2024-06-25                              73.30
# 1104 2024-06-26                              73.30
# 1105 2024-06-27                              73.30
# 1106 2024-06-28                              71.38
#
#       Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 0                                 53.22                              64.70
# 1                                 52.36                              63.10
# 2                                 52.36                              63.10
# ...

# %%
data1.isnull().sum()
# Out:
# Date                                    0
# Coal_RB_4800_FOB_London_Close_USD       0
# Coal_RB_5500_FOB_London_Close_USD       0
# Coal_RB_5700_FOB_London_Close_USD       0
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    0
# Coal_India_5500_CFR_London_Close_USD    0
# Price_WTI                               0
# Price_Brent_Oil                         0
# Price_Dubai_Brent_Oil                   0
# Price_ExxonMobil                        0
# Price_Shenhua                           0
# Price_All_Share                         0
# Price_Mining                            0
# Price_LNG_Japan_Korea_Marker_PLATTS     0
# Price_ZAR_USD                           0
# Price_Natural_Gas                       0
# Price_ICE                               0
# Price_Dutch_TTF                         0
# Price_Indian_en_exg_rate                0
# dtype: int64

# %%
data2 = data.fillna(value= mean)
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data2 = data.fillna(value= mean)
#       2 data2
#
# NameError: name 'mean' is not defined

# %%
data1.mean()
data1
# Out:
#            Date  Coal_RB_4800_FOB_London_Close_USD  \
# 0    2020-04-02                              41.00
# 1    2020-04-03                              40.34
# 2    2020-04-06                              40.34
# 3    2020-04-07                              40.34
# 4    2020-04-08                              40.34
# ...         ...                                ...
# 1102 2024-06-24                              73.30
# 1103 2024-06-25                              73.30
# 1104 2024-06-26                              73.30
# 1105 2024-06-27                              73.30
# 1106 2024-06-28                              71.38
#
#       Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 0                                 53.22                              64.70
# 1                                 52.36                              63.10
# 2                                 52.36                              63.10
# ...

# %%
data.mean()
# Out:
# Date                                    2022-05-16 14:22:26.341463296
# Coal_RB_4800_FOB_London_Close_USD                           87.953184
# Coal_RB_5500_FOB_London_Close_USD                          113.353155
# Coal_RB_5700_FOB_London_Close_USD                          134.971807
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD                       144.351494
# Coal_India_5500_CFR_London_Close_USD                        123.75971
# Price_WTI                                                   72.345469
# Price_Brent_Oil                                              76.28302
# Price_Dubai_Brent_Oil                                       74.752493
# Price_ExxonMobil                                            80.871012
# Price_Shenhua                                               21.274702
# Price_All_Share                                          68736.904811
# Price_Mining                                             52972.178374
# ...

# %%
data2= data.fillna(value = data.mean())
data2
# Out:
#            Date  Coal_RB_4800_FOB_London_Close_USD  \
# 0    2020-04-02                              41.00
# 1    2020-04-03                              40.34
# 2    2020-04-06                              40.34
# 3    2020-04-07                              40.34
# 4    2020-04-08                              40.34
# ...         ...                                ...
# 1102 2024-06-24                              73.30
# 1103 2024-06-25                              73.30
# 1104 2024-06-26                              73.30
# 1105 2024-06-27                              73.30
# 1106 2024-06-28                              71.38
#
#       Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 0                                 53.22                              64.70
# 1                                 52.36                              63.10
# 2                                 52.36                              63.10
# ...

# %%
data2.isnull().sum()
# Out:
# Date                                    0
# Coal_RB_4800_FOB_London_Close_USD       0
# Coal_RB_5500_FOB_London_Close_USD       0
# Coal_RB_5700_FOB_London_Close_USD       0
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    0
# Coal_India_5500_CFR_London_Close_USD    0
# Price_WTI                               0
# Price_Brent_Oil                         0
# Price_Dubai_Brent_Oil                   0
# Price_ExxonMobil                        0
# Price_Shenhua                           0
# Price_All_Share                         0
# Price_Mining                            0
# Price_LNG_Japan_Korea_Marker_PLATTS     0
# Price_ZAR_USD                           0
# Price_Natural_Gas                       0
# Price_ICE                               0
# Price_Dutch_TTF                         0
# Price_Indian_en_exg_rate                0
# dtype: int64

# %%
data2.mean()
# Out:
# Date                                    2022-05-16 14:22:26.341463296
# Coal_RB_4800_FOB_London_Close_USD                           87.953184
# Coal_RB_5500_FOB_London_Close_USD                          113.353155
# Coal_RB_5700_FOB_London_Close_USD                          134.971807
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD                       144.351494
# Coal_India_5500_CFR_London_Close_USD                        123.75971
# Price_WTI                                                   72.345469
# Price_Brent_Oil                                              76.28302
# Price_Dubai_Brent_Oil                                       74.752493
# Price_ExxonMobil                                            80.871012
# Price_Shenhua                                               21.274702
# Price_All_Share                                          68736.904811
# Price_Mining                                             52972.178374
# ...

# %%
data2.median()
# Out:
# Date                                    2022-05-17 00:00:00
# Coal_RB_4800_FOB_London_Close_USD                     77.81
# Coal_RB_5500_FOB_London_Close_USD                     97.28
# Coal_RB_5700_FOB_London_Close_USD                    110.94
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD                 115.63
# Coal_India_5500_CFR_London_Close_USD                 111.68
# Price_WTI                                             75.57
# Price_Brent_Oil                                       79.67
# Price_Dubai_Brent_Oil                                 78.18
# Price_ExxonMobil                                      84.81
# Price_Shenhua                                         21.85
# Price_All_Share                                    69401.95
# Price_Mining                                   52972.178374
# Price_LNG_Japan_Korea_Marker_PLATTS                  13.335
# Price_ZAR_USD                                       0.05872
# Price_Natural_Gas                                     2.879
# ...

# %%
import statistics
data2.round(2).mode()
# Out:
#            Date  Coal_RB_4800_FOB_London_Close_USD  \
# 0    2020-04-02                              87.95
# 1    2020-04-03                                NaN
# 2    2020-04-06                                NaN
# 3    2020-04-07                                NaN
# 4    2020-04-08                                NaN
# ...         ...                                ...
# 1102 2024-06-24                                NaN
# 1103 2024-06-25                                NaN
# 1104 2024-06-26                                NaN
# 1105 2024-06-27                                NaN
# 1106 2024-06-28                                NaN
#
#       Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 0                                113.35                             134.97
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# ...

# %%
import numpy as np
print(np.var(data2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 import numpy as np
# ----> 2 print(np.var(data2))
#
# File <__array_function__ internals>:200, in var(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3745, in var(a, axis, dtype, out, ddof, keepdims, where)
#    3743         pass
#    3744     else:
# -> 3745         return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3747 return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#    3748                      **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:11401, in NDFrame._add_numeric_operations.<locals>.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11383 @doc(
#   11384     _num_ddof_doc,
#   11385     desc="Return unbiased variance over requested axis.\n\nNormalized by "
# ...

# %%
data_only = data2.drop(columns=['Date'])
data_only
# Out:
#       Coal_RB_4800_FOB_London_Close_USD  Coal_RB_5500_FOB_London_Close_USD  \
# 0                                 41.00                              53.22
# 1                                 40.34                              52.36
# 2                                 40.34                              52.36
# 3                                 40.34                              52.36
# 4                                 40.34                              52.36
# ...                                 ...                                ...
# 1102                              73.30                              94.56
# 1103                              73.30                              94.56
# 1104                              73.30                              94.56
# 1105                              73.30                              94.56
# 1106                              71.38                              92.08
#
# ...

# %%
variances = data_only.var()
print(variances)
# Out:
# Coal_RB_4800_FOB_London_Close_USD       2.158715e+03
# Coal_RB_5500_FOB_London_Close_USD       3.841868e+03
# Coal_RB_5700_FOB_London_Close_USD       5.790329e+03
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    6.827288e+03
# Coal_India_5500_CFR_London_Close_USD    3.079917e+03
# Price_WTI                               4.215120e+02
# Price_Brent_Oil                         4.251792e+02
# Price_Dubai_Brent_Oil                   4.052808e+02
# Price_ExxonMobil                        7.433843e+02
# Price_Shenhua                           3.544100e+01
# Price_All_Share                         6.007824e+07
# Price_Mining                            4.733378e+07
# Price_LNG_Japan_Korea_Marker_PLATTS     1.557187e+02
# Price_ZAR_USD                           3.681609e-05
# Price_Natural_Gas                       3.664219e+00
# Price_ICE                               1.816855e+02
# Price_Dutch_TTF                         2.764264e+03
# Price_Indian_en_exg_rate                2.772874e+03
# ...

# %%
std_deviation = data_only.std()
print(std_deviation)
# Out:
# Coal_RB_4800_FOB_London_Close_USD         46.461976
# Coal_RB_5500_FOB_London_Close_USD         61.982802
# Coal_RB_5700_FOB_London_Close_USD         76.094209
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      82.627404
# Coal_India_5500_CFR_London_Close_USD      55.497003
# Price_WTI                                 20.530757
# Price_Brent_Oil                           20.619874
# Price_Dubai_Brent_Oil                     20.131586
# Price_ExxonMobil                          27.265075
# Price_Shenhua                              5.953235
# Price_All_Share                         7751.015722
# Price_Mining                            6879.955280
# Price_LNG_Japan_Korea_Marker_PLATTS       12.478731
# Price_ZAR_USD                              0.006068
# Price_Natural_Gas                          1.914215
# Price_ICE                                 13.479077
# Price_Dutch_TTF                           52.576264
# Price_Indian_en_exg_rate                  52.658082
# dtype: float64

# %%
ranges = data_only.max() - data_only.min()
print(ranges)
# Out:
# Coal_RB_4800_FOB_London_Close_USD         274.34000
# Coal_RB_5500_FOB_London_Close_USD         325.68000
# Coal_RB_5700_FOB_London_Close_USD         367.66000
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      383.69000
# Coal_India_5500_CFR_London_Close_USD      271.08000
# Price_WTI                                 161.33000
# Price_Brent_Oil                           108.65000
# Price_Dubai_Brent_Oil                     103.46000
# Price_ExxonMobil                           90.63000
# Price_Shenhua                              28.24000
# Price_All_Share                         36192.66000
# Price_Mining                            39927.46000
# Price_LNG_Japan_Korea_Marker_PLATTS        67.96000
# Price_ZAR_USD                               0.02388
# Price_Natural_Gas                           8.16500
# Price_ICE                                  58.44000
# Price_Dutch_TTF                           335.68500
# Price_Indian_en_exg_rate                  250.23000
# dtype: float64

# %%
skewness = data_only.skew()
print(skewness)
# Out:
# Coal_RB_4800_FOB_London_Close_USD       1.336514
# Coal_RB_5500_FOB_London_Close_USD       1.283273
# Coal_RB_5700_FOB_London_Close_USD       1.301123
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    1.282849
# Coal_India_5500_CFR_London_Close_USD    0.877831
# Price_WTI                              -0.538292
# Price_Brent_Oil                        -0.431779
# Price_Dubai_Brent_Oil                  -0.570439
# Price_ExxonMobil                       -0.211281
# Price_Shenhua                           0.583106
# Price_All_Share                        -0.839517
# Price_Mining                            0.295003
# Price_LNG_Japan_Korea_Marker_PLATTS     1.104863
# Price_ZAR_USD                           0.347963
# Price_Natural_Gas                       1.264581
# Price_ICE                               0.227101
# Price_Dutch_TTF                         1.744003
# Price_Indian_en_exg_rate                0.381738
# dtype: float64

# %%
kurtosis = data_only.kurt()
print(kurtosis)
# Out:
# Coal_RB_4800_FOB_London_Close_USD       2.303051
# Coal_RB_5500_FOB_London_Close_USD       1.277939
# Coal_RB_5700_FOB_London_Close_USD       0.950956
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    0.796499
# Coal_India_5500_CFR_London_Close_USD    0.292082
# Price_WTI                               0.836003
# Price_Brent_Oil                         0.005253
# Price_Dubai_Brent_Oil                   0.072906
# Price_ExxonMobil                       -1.429608
# Price_Shenhua                           0.209243
# Price_All_Share                         0.013746
# Price_Mining                           -0.240241
# Price_LNG_Japan_Korea_Marker_PLATTS     0.935122
# Price_ZAR_USD                          -1.217152
# Price_Natural_Gas                       0.686998
# Price_ICE                              -0.796873
# Price_Dutch_TTF                         3.325359
# Price_Indian_en_exg_rate                0.075783
# dtype: float64

# %%
data.hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()
